# %%
import numpy as np
import polars as pl
import pandas as pd
from sklearn.base import clone
from copy import deepcopy
import optuna
from scipy.optimize import minimize

import re
from colorama import Fore, Style

from tqdm import tqdm
from IPython.display import clear_output

import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

import lightgbm as lgb
from catboost import CatBoostRegressor, CatBoostClassifier
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.model_selection import *
from sklearn.metrics import *
import os

SEED = 42
n_splits = 5

# %% [markdown]
# # <p style="font-size:120%; text-align:center">Preprocess</p>

# %%
train = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/train.csv')
test = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/test.csv')
sample = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv')

def load_time_series(dirname) -> pd.DataFrame:
    ids = os.listdir(dirname)
    indexes = []
    stats = []
    for idname in tqdm(ids):
        df = pd.read_parquet(os.path.join(dirname, idname, 'part-0.parquet'))
        df.drop('step', axis=1, inplace=True)
        stats.append(df.describe().iloc[1:].values.reshape(-1))
        indexes.append(idname.split('=')[1])
    df = pd.DataFrame(stats, columns=[f"stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    return df
        
train_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet")
test_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet")
time_series_cols = train_ts.columns.tolist()
time_series_cols.remove("id")

train = pd.merge(train, train_ts, how="left", on='id')
test = pd.merge(test, test_ts, how="left", on='id')

train = train.drop('id',axis=1)
test = test.drop('id',axis=1)

featuresCols = ['Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
       'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
       'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
       'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
       'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
       'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
       'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
       'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
       'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
       'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
       'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
       'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
       'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
       'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
       'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
       'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
       'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
       'PreInt_EduHx-computerinternet_hoursday','sii']

featuresCols += time_series_cols

train = train[featuresCols]
train = train.dropna(subset='sii')

cat_c = ['Basic_Demos-Enroll_Season','CGAS-Season','Physical-Season','Fitness_Endurance-Season','FGC-Season',
 'BIA-Season','PAQ_A-Season','PAQ_C-Season','SDS-Season','PreInt_EduHx-Season']

def update(df):
    global cat_c
    for c in cat_c : 
        df[c] = df[c].fillna('Missing')
        df[c] = df[c].astype('category')
        
    return df
        
train = update(train)
test = update(test)

def create_mapping(column, dataset):
    unique_values = dataset[column].unique()
    return {value: idx for idx, value in enumerate(unique_values)}

for col in cat_c:

    mapping = create_mapping(col, train)
    mappingTe = create_mapping(col, test)
    
    train[col] = train[col].replace(mapping).astype(int)
    test[col] = test[col].replace(mappingTe).astype(int)
# Out:
# 100%|██████████| 996/996 [02:34<00:00,  6.45it/s]
# 100%|██████████| 2/2 [00:00<00:00,  8.38it/s]

# %%
print(train.shape)
train.head()
# Out:
# (2736, 143)
#    Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  CGAS-Season  \
# 0                          0                5                0            0
# 1                          1                9                0            1
# 2                          1               10                1            2
# 3                          2                9                0            2
# 5                          3               13                1            0
#
#    CGAS-CGAS_Score  Physical-Season  Physical-BMI  Physical-Height  \
# 0             51.0                0     16.877316             46.0
# 1              NaN                0     14.035590             48.0
# 2             71.0                0     16.648696             56.5
# 3             71.0                1     18.292347             56.0
# 5             50.0                1     22.279952             59.5
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
# 2             75.6                           NaN                   65.0
# 3             81.6                           NaN                   60.0
# 5            112.2                           NaN                   60.0
#
#    Physical-HeartRate  Physical-Systolic_BP  Fitness_Endurance-Season  \
# 0                 NaN                   NaN                         0
# 1                70.0                 122.0                         0
# 2                94.0                 117.0                         1
# 3                97.0                 117.0                         2
# 5                73.0                 102.0                         0
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          5.0                          7.0
# 3                          6.0                          9.0
# 5                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec  FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN           0         0.0              0.0
# 1                         NaN           0         3.0              0.0
# 2                        33.0           0        20.0              1.0
# 3                        37.0           1        18.0              1.0
# 5                         NaN           1        12.0              0.0
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
# 2          10.2                1.0         14.7               2.0         7.0
# 3           NaN                NaN          NaN               NaN         5.0
# 5          16.5                2.0         17.9               2.0         6.0
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
# 2              1.0         10.0               1.0         10.0
# 3              0.0          7.0               0.0          7.0
# 5              0.0         10.0               1.0         11.0
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone  BIA-Season  \
# 0               0.0         6.0              1.0           0
# 1               1.0         3.0              0.0           1
# 2               1.0         5.0              0.0           2
# 3               0.0         7.0              1.0           3
# 5               1.0         8.0              0.0           3
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
# 2                         NaN          NaN          NaN          NaN
# 3                         3.0      3.84191      18.2943     1131.430
# 5                         2.0      4.33036      30.1865     1330.970
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
# 2          NaN          NaN          NaN           NaN          NaN
# 3      1923.44     15.59250      62.7757       14.0740      4.22033
# 5      1996.45     30.21240      84.0285       16.6877     13.49880
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
# 2          NaN                NaN          NaN          NaN          NaN
# 3     18.82430                2.0      30.4041     16.77900      58.9338
# 5     67.97150                2.0      32.9141     20.90200      79.6982
#
#    BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-Season  PAQ_A-PAQ_A_Total  PAQ_C-Season  \
# 0      19.5413      32.6909             0                NaN             0
# 1      15.4107      27.0552             0                NaN             1
# 2          NaN          NaN             0                NaN             2
# 3      26.4798      45.9966             0                NaN             3
# 5      35.3804      63.1265             0                NaN             4
#
#    PAQ_C-PAQ_C_Total  SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN           0                NaN              NaN
# 1              2.340           1               46.0             64.0
# 2              2.170           1               38.0             54.0
# 3              2.451           2               31.0             45.0
# 5              4.110           2               40.0             56.0
#
#    PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday  sii    stat_0  \
# 0                    0                                     3.0  2.0       NaN
# 1                    1                                     0.0  0.0       NaN
# 2                    1                                     2.0  0.0       NaN
# 3                    2                                     0.0  1.0 -0.316384
# 5                    3                                     0.0  1.0 -0.004272
#
#      stat_1    stat_2    stat_3     stat_4    stat_5     stat_6       stat_7  \
# 0       NaN       NaN       NaN        NaN       NaN        NaN          NaN
# 1       NaN       NaN       NaN        NaN       NaN        NaN          NaN
# 2       NaN       NaN       NaN        NaN       NaN        NaN          NaN
# 3  0.016009 -0.167890  0.047388 -10.580416  0.000000  42.296310  4053.579102
# 5  0.016859 -0.631731  0.011926 -55.630768  0.655708  16.771982  3838.189453
#
#          stat_8    stat_9  stat_10    stat_11   stat_12   stat_13   stat_14  \
# 0           NaN       NaN      NaN        NaN       NaN       NaN       NaN
# 1           NaN       NaN      NaN        NaN       NaN       NaN       NaN
# 2           NaN       NaN      NaN        NaN       NaN       NaN       NaN
# 3  5.046215e+13  4.470182      3.0  53.201683  0.453665  0.502702  0.585710
# 5  4.321212e+13  3.909848      3.0  79.435593  0.351545  0.303812  0.623476
#
#     stat_15    stat_16   stat_17     stat_18     stat_19       stat_20  \
# 0       NaN        NaN       NaN         NaN         NaN           NaN
# 1       NaN        NaN       NaN         NaN         NaN           NaN
# 2       NaN        NaN       NaN         NaN         NaN           NaN
# 3  0.106351  42.947170  0.000000  208.168976  112.404045  1.942842e+13
# 5  0.024331  50.303635  0.468723   95.327438  155.573868  2.497264e+13
#
#     stat_21  stat_22    stat_23   stat_24   stat_25   stat_26  stat_27  \
# 0       NaN      NaN        NaN       NaN       NaN       NaN      NaN
# 1       NaN      NaN        NaN       NaN       NaN       NaN      NaN
# 2       NaN      NaN        NaN       NaN       NaN       NaN      NaN
# 3  1.931421      0.0  14.244914 -1.746094 -2.905339 -1.048372      0.0
# 5  1.946892      0.0   6.634319 -1.038711 -1.522690 -1.018787      0.0
#
#      stat_28  stat_29  stat_30      stat_31       stat_32  stat_33  stat_34  \
# 0        NaN      NaN      NaN          NaN           NaN      NaN      NaN
# 1        NaN      NaN      NaN          NaN           NaN      NaN      NaN
# 2        NaN      NaN      NaN          NaN           NaN      NaN      NaN
# 3 -89.833092      0.0      0.0  3824.000000  5.500000e+10      1.0      3.0
# 5 -88.761833      0.0      0.0  3098.166748  0.000000e+00      1.0      3.0
#
#    stat_35   stat_36   stat_37   stat_38   stat_39    stat_40  stat_41  \
# 0      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 1      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 2      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3     41.0 -0.684180 -0.309863 -0.649974  0.006432 -41.541863      0.0
# 5     68.0 -0.052803 -0.044517 -1.009344  0.008622 -88.386049      0.0
#
#     stat_42      stat_43       stat_44  stat_45  stat_46  stat_47   stat_48  \
# 0       NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 1       NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 2       NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 3  2.392969  4028.666748  3.689000e+13      3.0      3.0     42.0 -0.366849
# 5  0.500000  3747.000000  2.154000e+13      2.0      3.0     74.0 -0.020622
#
#     stat_49   stat_50   stat_51    stat_52  stat_53   stat_54  stat_55  \
# 0       NaN       NaN       NaN        NaN      NaN       NaN      NaN
# 1       NaN       NaN       NaN        NaN      NaN       NaN      NaN
# 2       NaN       NaN       NaN        NaN      NaN       NaN      NaN
# 3  0.024974 -0.245378  0.023637 -15.086617      0.0  6.926828   4070.0
# 5 -0.028179 -1.007728  0.009831 -86.119919      1.0  0.879005   3812.0
#
#         stat_56  stat_57  stat_58  stat_59   stat_60   stat_61   stat_62  \
# 0           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 2           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3  5.347750e+13      5.0      3.0     50.0 -0.010677  0.400677  0.204727
# 5  4.331000e+13      4.0      3.0     79.0 -0.019081  0.020307 -0.294459
#
#     stat_63    stat_64  stat_65    stat_66      stat_67       stat_68  \
# 0       NaN        NaN      NaN        NaN          NaN           NaN
# 1       NaN        NaN      NaN        NaN          NaN           NaN
# 2       NaN        NaN      NaN        NaN          NaN           NaN
# 3  0.041420  12.220764      0.0  15.000000  4147.000000  6.640875e+13
# 5  0.010668 -17.483364      1.0   6.141348  3951.187561  6.485500e+13
#
#    stat_69  stat_70  stat_71   stat_72   stat_73   stat_74   stat_75  \
# 0      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 1      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 2      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 3      6.0      3.0     53.0  1.507865  1.666354  1.546979  4.004276
# 5      6.0      3.0     85.0  1.034351  1.946303  1.146284  2.952888
#
#      stat_76  stat_77      stat_78  stat_79       stat_80  stat_81  stat_82  \
# 0        NaN      NaN          NaN      NaN           NaN      NaN      NaN
# 1        NaN      NaN          NaN      NaN           NaN      NaN      NaN
# 2        NaN      NaN          NaN      NaN           NaN      NaN      NaN
# 3  89.751656      0.0  2633.250000   4188.5  8.611000e+13      7.0      3.0
# 5  89.476036      1.0  2597.800049   4175.0  8.639500e+13      7.0      3.0
#
#    stat_83
# 0      NaN
# 1      NaN
# 2      NaN
# 3     85.0
# 5     91.0

# %%
print(test.shape)
test.head()
# Out:
# (20, 142)
#    Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  CGAS-Season  \
# 0                          0                5                0            0
# 1                          1                9                0            1
# 2                          1               10                1            2
# 3                          2                9                0            2
# 4                          3               18                1            3
#
#    CGAS-CGAS_Score  Physical-Season  Physical-BMI  Physical-Height  \
# 0             51.0                0     16.877316             46.0
# 1              NaN                0     14.035590             48.0
# 2             71.0                0     16.648696             56.5
# 3             71.0                1     18.292347             56.0
# 4              NaN                2           NaN              NaN
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
# 2             75.6                           NaN                   65.0
# 3             81.6                           NaN                   60.0
# 4              NaN                           NaN                    NaN
#
#    Physical-HeartRate  Physical-Systolic_BP  Fitness_Endurance-Season  \
# 0                 NaN                   NaN                         0
# 1                70.0                 122.0                         0
# 2                94.0                 117.0                         1
# 3                97.0                 117.0                         2
# 4                 NaN                   NaN                         0
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          5.0                          7.0
# 3                          6.0                          9.0
# 4                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec  FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN           0         0.0              0.0
# 1                         NaN           0         3.0              0.0
# 2                        33.0           0        20.0              1.0
# 3                        37.0           1        18.0              1.0
# 4                         NaN           2         NaN              NaN
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
# 2          10.2                1.0         14.7               2.0         7.0
# 3           NaN                NaN          NaN               NaN         5.0
# 4           NaN                NaN          NaN               NaN         NaN
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
# 2              1.0         10.0               1.0         10.0
# 3              0.0          7.0               0.0          7.0
# 4              NaN          NaN               NaN          NaN
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone  BIA-Season  \
# 0               0.0         6.0              1.0           0
# 1               1.0         3.0              0.0           1
# 2               1.0         5.0              0.0           2
# 3               0.0         7.0              1.0           3
# 4               NaN         NaN              NaN           2
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
# 2                         NaN          NaN          NaN          NaN
# 3                         3.0      3.84191      18.2943     1131.430
# 4                         NaN          NaN          NaN          NaN
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
# 2          NaN          NaN          NaN           NaN          NaN
# 3      1923.44     15.59250      62.7757       14.0740      4.22033
# 4          NaN          NaN          NaN           NaN          NaN
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
# 2          NaN                NaN          NaN          NaN          NaN
# 3     18.82430                2.0      30.4041     16.77900      58.9338
# 4          NaN                NaN          NaN          NaN          NaN
#
#    BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-Season  PAQ_A-PAQ_A_Total  PAQ_C-Season  \
# 0      19.5413      32.6909             0                NaN             0
# 1      15.4107      27.0552             0                NaN             1
# 2          NaN          NaN             0                NaN             2
# 3      26.4798      45.9966             0                NaN             3
# 4          NaN          NaN             1               1.04             0
#
#    PAQ_C-PAQ_C_Total  SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN           0                NaN              NaN
# 1              2.340           1               46.0             64.0
# 2              2.170           1               38.0             54.0
# 3              2.451           2               31.0             45.0
# 4                NaN           0                NaN              NaN
#
#    PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday    stat_0  \
# 0                    0                                     3.0       NaN
# 1                    1                                     0.0       NaN
# 2                    1                                     2.0       NaN
# 3                    2                                     0.0 -0.316384
# 4                    3                                     NaN       NaN
#
#      stat_1   stat_2    stat_3     stat_4  stat_5    stat_6       stat_7  \
# 0       NaN      NaN       NaN        NaN     NaN       NaN          NaN
# 1       NaN      NaN       NaN        NaN     NaN       NaN          NaN
# 2       NaN      NaN       NaN        NaN     NaN       NaN          NaN
# 3  0.016009 -0.16789  0.047388 -10.580416     0.0  42.29631  4053.579102
# 4       NaN      NaN       NaN        NaN     NaN       NaN          NaN
#
#          stat_8    stat_9  stat_10    stat_11   stat_12   stat_13  stat_14  \
# 0           NaN       NaN      NaN        NaN       NaN       NaN      NaN
# 1           NaN       NaN      NaN        NaN       NaN       NaN      NaN
# 2           NaN       NaN      NaN        NaN       NaN       NaN      NaN
# 3  5.046215e+13  4.470182      3.0  53.201683  0.453665  0.502702  0.58571
# 4           NaN       NaN      NaN        NaN       NaN       NaN      NaN
#
#     stat_15   stat_16  stat_17     stat_18     stat_19       stat_20  \
# 0       NaN       NaN      NaN         NaN         NaN           NaN
# 1       NaN       NaN      NaN         NaN         NaN           NaN
# 2       NaN       NaN      NaN         NaN         NaN           NaN
# 3  0.106351  42.94717      0.0  208.168976  112.404045  1.942842e+13
# 4       NaN       NaN      NaN         NaN         NaN           NaN
#
#     stat_21  stat_22    stat_23   stat_24   stat_25   stat_26  stat_27  \
# 0       NaN      NaN        NaN       NaN       NaN       NaN      NaN
# 1       NaN      NaN        NaN       NaN       NaN       NaN      NaN
# 2       NaN      NaN        NaN       NaN       NaN       NaN      NaN
# 3  1.931421      0.0  14.244914 -1.746094 -2.905339 -1.048372      0.0
# 4       NaN      NaN        NaN       NaN       NaN       NaN      NaN
#
#      stat_28  stat_29  stat_30  stat_31       stat_32  stat_33  stat_34  \
# 0        NaN      NaN      NaN      NaN           NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN           NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN           NaN      NaN      NaN
# 3 -89.833092      0.0      0.0   3824.0  5.500000e+10      1.0      3.0
# 4        NaN      NaN      NaN      NaN           NaN      NaN      NaN
#
#    stat_35  stat_36   stat_37   stat_38   stat_39    stat_40  stat_41  \
# 0      NaN      NaN       NaN       NaN       NaN        NaN      NaN
# 1      NaN      NaN       NaN       NaN       NaN        NaN      NaN
# 2      NaN      NaN       NaN       NaN       NaN        NaN      NaN
# 3     41.0 -0.68418 -0.309863 -0.649974  0.006432 -41.541863      0.0
# 4      NaN      NaN       NaN       NaN       NaN        NaN      NaN
#
#     stat_42      stat_43       stat_44  stat_45  stat_46  stat_47   stat_48  \
# 0       NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 1       NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 2       NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 3  2.392969  4028.666748  3.689000e+13      3.0      3.0     42.0 -0.366849
# 4       NaN          NaN           NaN      NaN      NaN      NaN       NaN
#
#     stat_49   stat_50   stat_51    stat_52  stat_53   stat_54  stat_55  \
# 0       NaN       NaN       NaN        NaN      NaN       NaN      NaN
# 1       NaN       NaN       NaN        NaN      NaN       NaN      NaN
# 2       NaN       NaN       NaN        NaN      NaN       NaN      NaN
# 3  0.024974 -0.245378  0.023637 -15.086617      0.0  6.926828   4070.0
# 4       NaN       NaN       NaN        NaN      NaN       NaN      NaN
#
#         stat_56  stat_57  stat_58  stat_59   stat_60   stat_61   stat_62  \
# 0           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 2           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3  5.347750e+13      5.0      3.0     50.0 -0.010677  0.400677  0.204727
# 4           NaN      NaN      NaN      NaN       NaN       NaN       NaN
#
#    stat_63    stat_64  stat_65  stat_66  stat_67       stat_68  stat_69  \
# 0      NaN        NaN      NaN      NaN      NaN           NaN      NaN
# 1      NaN        NaN      NaN      NaN      NaN           NaN      NaN
# 2      NaN        NaN      NaN      NaN      NaN           NaN      NaN
# 3  0.04142  12.220764      0.0     15.0   4147.0  6.640875e+13      6.0
# 4      NaN        NaN      NaN      NaN      NaN           NaN      NaN
#
#    stat_70  stat_71   stat_72   stat_73   stat_74   stat_75    stat_76  \
# 0      NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 1      NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 2      NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 3      3.0     53.0  1.507865  1.666354  1.546979  4.004276  89.751656
# 4      NaN      NaN       NaN       NaN       NaN       NaN        NaN
#
#    stat_77  stat_78  stat_79       stat_80  stat_81  stat_82  stat_83
# 0      NaN      NaN      NaN           NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN           NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN           NaN      NaN      NaN      NaN
# 3      0.0  2633.25   4188.5  8.611000e+13      7.0      3.0     85.0
# 4      NaN      NaN      NaN           NaN      NaN      NaN      NaN

# %%
missing = pd.DataFrame(train.isna().sum().sort_values(ascending=False)).rename(columns={0:"Missing Count"})
missing['Data Loss(%)'] = missing['Missing Count'] / train.shape[0] * 100
missing.style.background_gradient()
# Out:
# <style type="text/css">
# #T_d3ef0_row0_col0, #T_d3ef0_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d3ef0_row1_col0, #T_d3ef0_row1_col1 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_d3ef0_row2_col0, #T_d3ef0_row2_col1, #T_d3ef0_row3_col0, #T_d3ef0_row3_col1, #T_d3ef0_row4_col0, #T_d3ef0_row4_col1 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_d3ef0_row5_col0, #T_d3ef0_row5_col1, #T_d3ef0_row6_col0, #T_d3ef0_row6_col1, #T_d3ef0_row7_col0, #T_d3ef0_row7_col1, #T_d3ef0_row8_col0, #T_d3ef0_row8_col1 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_d3ef0_row9_col0, #T_d3ef0_row9_col1, #T_d3ef0_row10_col0, #T_d3ef0_row10_col1, #T_d3ef0_row11_col0, #T_d3ef0_row11_col1, #T_d3ef0_row12_col0, #T_d3ef0_row12_col1, #T_d3ef0_row13_col0, #T_d3ef0_row13_col1, #T_d3ef0_row14_col0, #T_d3ef0_row14_col1, #T_d3ef0_row15_col0, #T_d3ef0_row15_col1, #T_d3ef0_row16_col0, #T_d3ef0_row16_col1, #T_d3ef0_row17_col0, #T_d3ef0_row17_col1, #T_d3ef0_row18_col0, #T_d3ef0_row18_col1, #T_d3ef0_row19_col0, #T_d3ef0_row19_col1, #T_d3ef0_row20_col0, #T_d3ef0_row20_col1, #T_d3ef0_row21_col0, #T_d3ef0_row21_col1, #T_d3ef0_row22_col0, #T_d3ef0_row22_col1, #T_d3ef0_row23_col0, #T_d3ef0_row23_col1, #T_d3ef0_row24_col0, #T_d3ef0_row24_col1, #T_d3ef0_row25_col0, #T_d3ef0_row25_col1, #T_d3ef0_row26_col0, #T_d3ef0_row26_col1, #T_d3ef0_row27_col0, #T_d3ef0_row27_col1, #T_d3ef0_row28_col0, #T_d3ef0_row28_col1, #T_d3ef0_row29_col0, #T_d3ef0_row29_col1, #T_d3ef0_row30_col0, #T_d3ef0_row30_col1, #T_d3ef0_row31_col0, #T_d3ef0_row31_col1, #T_d3ef0_row32_col0, #T_d3ef0_row32_col1, #T_d3ef0_row33_col0, #T_d3ef0_row33_col1, #T_d3ef0_row34_col0, #T_d3ef0_row34_col1, #T_d3ef0_row35_col0, #T_d3ef0_row35_col1, #T_d3ef0_row36_col0, #T_d3ef0_row36_col1, #T_d3ef0_row37_col0, #T_d3ef0_row37_col1, #T_d3ef0_row38_col0, #T_d3ef0_row38_col1, #T_d3ef0_row39_col0, #T_d3ef0_row39_col1, #T_d3ef0_row40_col0, #T_d3ef0_row40_col1, #T_d3ef0_row41_col0, #T_d3ef0_row41_col1, #T_d3ef0_row42_col0, #T_d3ef0_row42_col1, #T_d3ef0_row43_col0, #T_d3ef0_row43_col1, #T_d3ef0_row44_col0, #T_d3ef0_row44_col1, #T_d3ef0_row45_col0, #T_d3ef0_row45_col1, #T_d3ef0_row46_col0, #T_d3ef0_row46_col1, #T_d3ef0_row47_col0, #T_d3ef0_row47_col1, #T_d3ef0_row48_col0, #T_d3ef0_row48_col1, #T_d3ef0_row49_col0, #T_d3ef0_row49_col1, #T_d3ef0_row50_col0, #T_d3ef0_row50_col1, #T_d3ef0_row51_col0, #T_d3ef0_row51_col1, #T_d3ef0_row52_col0, #T_d3ef0_row52_col1, #T_d3ef0_row53_col0, #T_d3ef0_row53_col1, #T_d3ef0_row54_col0, #T_d3ef0_row54_col1, #T_d3ef0_row55_col0, #T_d3ef0_row55_col1, #T_d3ef0_row56_col0, #T_d3ef0_row56_col1, #T_d3ef0_row57_col0, #T_d3ef0_row57_col1, #T_d3ef0_row58_col0, #T_d3ef0_row58_col1, #T_d3ef0_row59_col0, #T_d3ef0_row59_col1, #T_d3ef0_row60_col0, #T_d3ef0_row60_col1, #T_d3ef0_row61_col0, #T_d3ef0_row61_col1, #T_d3ef0_row62_col0, #T_d3ef0_row62_col1, #T_d3ef0_row63_col0, #T_d3ef0_row63_col1, #T_d3ef0_row64_col0, #T_d3ef0_row64_col1, #T_d3ef0_row65_col0, #T_d3ef0_row65_col1, #T_d3ef0_row66_col0, #T_d3ef0_row66_col1, #T_d3ef0_row67_col0, #T_d3ef0_row67_col1, #T_d3ef0_row68_col0, #T_d3ef0_row68_col1, #T_d3ef0_row69_col0, #T_d3ef0_row69_col1, #T_d3ef0_row70_col0, #T_d3ef0_row70_col1, #T_d3ef0_row71_col0, #T_d3ef0_row71_col1, #T_d3ef0_row72_col0, #T_d3ef0_row72_col1, #T_d3ef0_row73_col0, #T_d3ef0_row73_col1, #T_d3ef0_row74_col0, #T_d3ef0_row74_col1, #T_d3ef0_row75_col0, #T_d3ef0_row75_col1, #T_d3ef0_row76_col0, #T_d3ef0_row76_col1, #T_d3ef0_row77_col0, #T_d3ef0_row77_col1, #T_d3ef0_row78_col0, #T_d3ef0_row78_col1, #T_d3ef0_row79_col0, #T_d3ef0_row79_col1, #T_d3ef0_row80_col0, #T_d3ef0_row80_col1, #T_d3ef0_row81_col0, #T_d3ef0_row81_col1, #T_d3ef0_row82_col0, #T_d3ef0_row82_col1, #T_d3ef0_row83_col0, #T_d3ef0_row83_col1, #T_d3ef0_row84_col0, #T_d3ef0_row84_col1, #T_d3ef0_row85_col0, #T_d3ef0_row85_col1, #T_d3ef0_row86_col0, #T_d3ef0_row86_col1, #T_d3ef0_row87_col0, #T_d3ef0_row87_col1, #T_d3ef0_row88_col0, #T_d3ef0_row88_col1, #T_d3ef0_row89_col0, #T_d3ef0_row89_col1, #T_d3ef0_row90_col0, #T_d3ef0_row90_col1, #T_d3ef0_row91_col0, #T_d3ef0_row91_col1, #T_d3ef0_row92_col0, #T_d3ef0_row92_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_d3ef0_row93_col0, #T_d3ef0_row93_col1 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_d3ef0_row94_col0, #T_d3ef0_row94_col1, #T_d3ef0_row95_col0, #T_d3ef0_row95_col1, #T_d3ef0_row96_col0, #T_d3ef0_row96_col1, #T_d3ef0_row97_col0, #T_d3ef0_row97_col1, #T_d3ef0_row98_col0, #T_d3ef0_row98_col1, #T_d3ef0_row99_col0, #T_d3ef0_row99_col1, #T_d3ef0_row100_col0, #T_d3ef0_row100_col1, #T_d3ef0_row101_col0, #T_d3ef0_row101_col1, #T_d3ef0_row102_col0, #T_d3ef0_row102_col1, #T_d3ef0_row103_col0, #T_d3ef0_row103_col1, #T_d3ef0_row104_col0, #T_d3ef0_row104_col1, #T_d3ef0_row105_col0, #T_d3ef0_row105_col1, #T_d3ef0_row106_col0, #T_d3ef0_row106_col1, #T_d3ef0_row107_col0, #T_d3ef0_row107_col1, #T_d3ef0_row108_col0, #T_d3ef0_row108_col1, #T_d3ef0_row109_col0, #T_d3ef0_row109_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_d3ef0_row110_col0, #T_d3ef0_row110_col1, #T_d3ef0_row111_col0, #T_d3ef0_row111_col1, #T_d3ef0_row112_col0, #T_d3ef0_row112_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_d3ef0_row113_col0, #T_d3ef0_row113_col1, #T_d3ef0_row114_col0, #T_d3ef0_row114_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_d3ef0_row115_col0, #T_d3ef0_row115_col1, #T_d3ef0_row116_col0, #T_d3ef0_row116_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_d3ef0_row117_col0, #T_d3ef0_row117_col1, #T_d3ef0_row118_col0, #T_d3ef0_row118_col1, #T_d3ef0_row119_col0, #T_d3ef0_row119_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_d3ef0_row120_col0, #T_d3ef0_row120_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_d3ef0_row121_col0, #T_d3ef0_row121_col1, #T_d3ef0_row122_col0, #T_d3ef0_row122_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_d3ef0_row123_col0, #T_d3ef0_row123_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d3ef0_row124_col0, #T_d3ef0_row124_col1, #T_d3ef0_row125_col0, #T_d3ef0_row125_col1, #T_d3ef0_row126_col0, #T_d3ef0_row126_col1, #T_d3ef0_row127_col0, #T_d3ef0_row127_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d3ef0_row128_col0, #T_d3ef0_row128_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_d3ef0_row129_col0, #T_d3ef0_row129_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d3ef0_row130_col0, #T_d3ef0_row130_col1, #T_d3ef0_row131_col0, #T_d3ef0_row131_col1, #T_d3ef0_row132_col0, #T_d3ef0_row132_col1, #T_d3ef0_row133_col0, #T_d3ef0_row133_col1, #T_d3ef0_row134_col0, #T_d3ef0_row134_col1, #T_d3ef0_row135_col0, #T_d3ef0_row135_col1, #T_d3ef0_row136_col0, #T_d3ef0_row136_col1, #T_d3ef0_row137_col0, #T_d3ef0_row137_col1, #T_d3ef0_row138_col0, #T_d3ef0_row138_col1, #T_d3ef0_row139_col0, #T_d3ef0_row139_col1, #T_d3ef0_row140_col0, #T_d3ef0_row140_col1, #T_d3ef0_row141_col0, #T_d3ef0_row141_col1, #T_d3ef0_row142_col0, #T_d3ef0_row142_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_d3ef0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3ef0_level0_col0" class="col_heading level0 col0" >Missing Count</th>
#       <th id="T_d3ef0_level0_col1" class="col_heading level0 col1" >Data Loss(%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3ef0_level0_row0" class="row_heading level0 row0" >PAQ_A-PAQ_A_Total</th>
#       <td id="T_d3ef0_row0_col0" class="data row0 col0" >2373</td>
#       <td id="T_d3ef0_row0_col1" class="data row0 col1" >86.732456</td>
#     </tr>
#     <tr>
#       <th id="T_d3ef0_level0_row1" class="row_heading level0 row1" >Physical-Waist_Circumference</th>
#       <td id="T_d3ef0_row1_col0" class="data row1 col0" >2253</td>
#       <td id="T_d3ef0_row1_col1" class="data row1 col1" >82.346491</td>
#     </tr>
#     <tr>
#       <th id="T_d3ef0_level0_row2" class="row_heading level0 row2" >Fitness_Endurance-Time_Sec</th>
#       <td id="T_d3ef0_row2_col0" class="data row2 col0" >2008</td>
#       <td id="T_d3ef0_

# %%
drop_threshold = 70 # Drop column that misses more than 70% of its value
remain_features = [ft for ft in list(train.columns) if ft in missing[missing['Data Loss(%)']<=70].index.tolist()]
remain_features
# Out:
# ['Basic_Demos-Enroll_Season',
#  'Basic_Demos-Age',
#  'Basic_Demos-Sex',
#  'CGAS-Season',
#  'CGAS-CGAS_Score',
#  'Physical-Season',
#  'Physical-BMI',
#  'Physical-Height',
#  'Physical-Weight',
#  'Physical-Diastolic_BP',
#  'Physical-HeartRate',
#  'Physical-Systolic_BP',
#  'Fitness_Endurance-Season',
#  'FGC-Season',
#  'FGC-FGC_CU',
#  'FGC-FGC_CU_Zone',
#  'FGC-FGC_GSND',
#  'FGC-FGC_GSND_Zone',
#  'FGC-FGC_GSD',
#  'FGC-FGC_GSD_Zone',
#  'FGC-FGC_PU',
#  'FGC-FGC_PU_Zone',
#  'FGC-FGC_SRL',
#  'FGC-FGC_SRL_Zone',
#  'FGC-FGC_SRR',
#  'FGC-FGC_SRR_Zone',
#  'FGC-FGC_TL',
#  'FGC-FGC_TL_Zone',
#  'BIA-Season',
#  'BIA-BIA_Activity_Level_num',
#  'BIA-BIA_BMC',
#  'BIA-BIA_BMI',
#  'BIA-BIA_BMR',
#  'BIA-BIA_DEE',
#  'BIA-BIA_ECW',
#  'BIA-BIA_FFM',
#  'BIA-BIA_FFMI',
#  'BIA-BIA_FMI',
#  'BIA-BIA_Fat',
#  'BIA-BIA_Frame_num',
#  'BIA-BIA_ICW',
#  'BIA-BIA_LDM',
#  'BIA-BIA_LST',
#  'BIA-BIA_SMM',
#  'BIA-BIA_TBW',
#  'PAQ_A-Season',
#  'PAQ_C-Season',
#  'PAQ_C-PAQ_C_Total',
#  'SDS-Season',
#  'SDS-SDS_Total_Raw',
#  'SDS-SDS_Total_T',
#  'PreInt_EduHx-Season',
#  'PreInt_EduHx-computerinternet_hoursday',
#  'sii',
#  'stat_0',
#  'stat_1',
#  'stat_2',
#  'stat_3',
#  'stat_4',
#  'stat_5',
#  'stat_6',
#  'stat_7',
#  'stat_8',
#  'stat_9',
#  'stat_10',
#  'stat_11',
#  'stat_12',
#  'stat_13',
#  'stat_14',
#  'stat_15',
#  'stat_16',
#  'stat_17',
#  'stat_18',
#  'stat_19',
#  'stat_20',
#  'stat_21',
#  'stat_22',
#  'stat_23',
#  'stat_24',
#  'stat_25',
#  'stat_26',
#  'stat_27',
#  'stat_28',
#  'stat_29',
#  'stat_30',
#  'stat_31',
#  'stat_32',
#  'stat_33',
#  'stat_34',
#  'stat_35',
#  'stat_36',
#  'stat_37',
#  'stat_38',
#  'stat_39',
#  'stat_40',
#  'stat_41',
#  'stat_42',
#  'stat_43',
#  'stat_44',
#  'stat_45',
#  'stat_46',
#  'stat_47',
#  'stat_48',
#  'stat_49',
#  'stat_50',
#  'stat_51',
#  'stat_52',
#  'stat_53',
#  'stat_54',
#  'stat_55',
#  'stat_56',
#  'stat_57',
#  'stat_58',
#  'stat_59',
#  'stat_60',
#  'stat_61',
#  'stat_62',
#  'stat_63',
#  'stat_64',
#  'stat_65',
#  'stat_66',
#  'stat_67',
#  'stat_68',
#  'stat_69',
#  'stat_70',
#  'stat_71',
#  'stat_72',
#  'stat_73',
#  'stat_74',
#  'stat_75',
#  'stat_76',
#  'stat_77',
#  'stat_78',
#  'stat_79',
#  'stat_80',
#  'stat_81',
#  'stat_82',
#  'stat_83']

# %%
train = train[remain_features]
test = test[[ft for ft in remain_features if ft != 'sii']]

# %% [markdown]
# # <p style="font-size:120%; text-align:center">Model</p>

# %%
def quadratic_weighted_kappa(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

def threshold_Rounder(oof_non_rounded, thresholds):
    return np.where(oof_non_rounded < thresholds[0], 0,
                    np.where(oof_non_rounded < thresholds[1], 1,
                             np.where(oof_non_rounded < thresholds[2], 2, 3)))

def evaluate_predictions(thresholds, y_true, oof_non_rounded):
    rounded_p = threshold_Rounder(oof_non_rounded, thresholds)
    return -quadratic_weighted_kappa(y_true, rounded_p)

def TrainML(model_class, test_data, tune=False):
    
    X = train.drop(['sii'], axis=1)
    y = train['sii']

    
    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = clone(model_class)
        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)
        
        test_preds[:, fold] = model.predict(test_data)
        
        print(f"Fold {fold+1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")
        clear_output(wait=True)

    print(f"Mean Train QWK --> {np.mean(train_S):.4f}")
    print(f"Mean Validation QWK ---> {np.mean(test_S):.4f}")

    KappaOPtimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.5, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead') # Nelder-Mead | # Powell
    assert KappaOPtimizer.success, "Optimization did not converge."
    
    oof_tuned = threshold_Rounder(oof_non_rounded, KappaOPtimizer.x)
    tKappa = quadratic_weighted_kappa(y, oof_tuned)

    print(f"----> || Optimized QWK SCORE :: {Fore.CYAN}{Style.BRIGHT} {tKappa:.3f}{Style.RESET_ALL}")
    
    if tune:
        return np.mean(test_S)

    tpm = test_preds.mean(axis=1)
    tpTuned = threshold_Rounder(tpm, KappaOPtimizer.x)
    
    submission = pd.DataFrame({
        'id': sample['id'],
        'sii': tpTuned
    })
    return submission

# %%
# # Custom objective functions
# def objective(trial):
#      # Define the hyperparameter space to be adjusted
#     params = {
#         'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
#         'max_depth': trial.suggest_int('max_depth', 3, 12),
#         'num_leaves': trial.suggest_int('num_leaves', 31, 512),
#         'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),
#         'feature_fraction': trial.suggest_uniform('feature_fraction', 0.5, 1.0),
#         'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.5, 1.0),
#         'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
#         'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
#         'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
#     }

#     Light = lgb.LGBMRegressor(**params,random_state=SEED, verbose=-1,n_estimators=200)
#     return TrainML(Light, test, True)

# # Create an Optuna Study
# study = optuna.create_study(direction='maximize')  
# study.optimize(objective, n_trials=100)  # 设置进行100次搜索 Set 100 searches

# # Output optimal hyperparameters and optimal results
# print("Best trial:")
# trial = study.best_trial

# print(f"   {trial.value}")
# print("  Best hyperparameters: ", trial.params)

# %%
# # Best trial:
# #    0.40180590915921055
# #   Best hyperparameters:  {'learning_rate': 0.09056475084257094, 'max_depth': 5, 'num_leaves': 429, 'min_data_in_leaf': 43, 'feature_fraction': 0.8916815865803562, 'bagging_fraction': 0.8276271977726875, 'bagging_freq': 6, 'lambda_l1': 0.07688998999378223, 'lambda_l2': 0.00026663802273190103}

Params = {'learning_rate': 0.09056475084257094, 'max_depth': 5, 'num_leaves': 429, 'min_data_in_leaf': 43, 
          'feature_fraction': 0.8916815865803562, 'bagging_fraction': 0.8276271977726875, 'bagging_freq': 6, 
          'lambda_l1': 0.07688998999378223, 'lambda_l2': 0.00026663802273190103}


Light = lgb.LGBMRegressor(**Params,random_state=SEED, verbose=-1,n_estimators=200)
Submission = TrainML(Light,test)
# Out:
# Training Folds: 100%|██████████| 5/5 [00:03<00:00,  1.62it/s]
# Mean Train QWK --> 0.7714
# Mean Validation QWK ---> 0.3853
# ----> || Optimized QWK SCORE ::  0.432

# %%
Submission.to_csv('submission.csv', index=False)
Submission.head()
print(Submission['sii'].value_counts())
# Out:
# sii
# 1    11
# 0     9
# Name: count, dtype: int64

# %%
Submission
# Out:
#           id  sii
# 0   00008ff9    1
# 1   000fd460    0
# 2   00105258    0
# 3   00115b9f    0
# 4   0016bb22    1
# 5   001f3379    1
# 6   0038ba98    0
# 7   0068a485    0
# 8   0069fbed    1
# 9   0083e397    1
# 10  0087dd65    0
# 11  00abe655    1
# 12  00ae59c9    1
# 13  00af6387    1
# 14  00bd4359    1
# 15  00c0cd71    1
# 16  00d56d4b    0
# 17  00d9913d    0
# 18  00e6167c    0
# 19  00ebc35d    1

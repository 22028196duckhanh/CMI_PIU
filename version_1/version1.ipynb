# %%
import numpy as np, pandas as pd, os
from sklearn.model_selection import cross_val_score, StratifiedKFold
import xgboost as xgb
import plotly.express as px, seaborn as sns, matplotlib.pyplot as plt
sns.set_style('darkgrid')
from sklearn.metrics import make_scorer, cohen_kappa_score
import eli5
from eli5.sklearn import PermutationImportance
import warnings
warnings.simplefilter('ignore')

# %%
train = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/test.csv', index_col='id')
data_dict = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/data_dictionary.csv')

# %% [markdown]
# ## Data preprocessing

# %%
print("Train shape:", train.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (3960, 81)
# Test shape: (20, 58)

# %%
# handle missing value and convert from string to num in categorical features
train_cat_cols = train.select_dtypes(exclude='number').columns
for col in train_cat_cols: 
    train[col] = train[col].replace({'Spring':1,'Summer':2,"Fall":3,"Winter":4})
    train[col] = train[col].fillna(0)

test_cat_cols = test.select_dtypes(exclude='number').columns
for col in test_cat_cols:
    test[col] = test[col].replace({'Spring':1,'Summer':2,"Fall":3,"Winter":4})
    test[col] = test[col].fillna(0)

# %% [markdown]
# ### PCIAT score ranges
# - 0-30 => sii = 0
# - 31-49 => sii = 1
# - 50-79 => sii = 2
# - 80-100 => sii = 3

# %%
PCIAT_cols = [val for val in train.columns[train.columns.str.contains('PCIAT')]] # Columns that contain "PCIAT"
PCIAT_cor = pd.DataFrame(train[PCIAT_cols].corr()['PCIAT-PCIAT_Total'].sort_values(ascending=False))
PCIAT_cor.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c2033_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c2033_row1_col0 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_c2033_row2_col0, #T_c2033_row3_col0, #T_c2033_row4_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_c2033_row5_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_c2033_row6_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_c2033_row7_col0, #T_c2033_row8_col0, #T_c2033_row9_col0 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_c2033_row10_col0 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_c2033_row11_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_c2033_row12_col0 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_c2033_row13_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_c2033_row14_col0, #T_c2033_row15_col0 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_c2033_row16_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_c2033_row17_col0 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_c2033_row18_col0 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_c2033_row19_col0 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_c2033_row20_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_c2033_row21_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_c2033">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2033_level0_col0" class="col_heading level0 col0" >PCIAT-PCIAT_Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2033_level0_row0" class="row_heading level0 row0" >PCIAT-PCIAT_Total</th>
#       <td id="T_c2033_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row1" class="row_heading level0 row1" >PCIAT-PCIAT_05</th>
#       <td id="T_c2033_row1_col0" class="data row1 col0" >0.830993</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row2" class="row_heading level0 row2" >PCIAT-PCIAT_15</th>
#       <td id="T_c2033_row2_col0" class="data row2 col0" >0.823996</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row3" class="row_heading level0 row3" >PCIAT-PCIAT_17</th>
#       <td id="T_c2033_row3_col0" class="data row3 col0" >0.823708</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row4" class="row_heading level0 row4" >PCIAT-PCIAT_03</th>
#       <td id="T_c2033_row4_col0" class="data row4 col0" >0.823336</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row5" class="row_heading level0 row5" >PCIAT-PCIAT_18</th>
#       <td id="T_c2033_row5_col0" class="data row5 col0" >0.802030</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row6" class="row_heading level0 row6" >PCIAT-PCIAT_02</th>
#       <td id="T_c2033_row6_col0" class="data row6 col0" >0.788802</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row7" class="row_heading level0 row7" >PCIAT-PCIAT_13</th>
#       <td id="T_c2033_row7_col0" class="data row7 col0" >0.771990</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row8" class="row_heading level0 row8" >PCIAT-PCIAT_08</th>
#       <td id="T_c2033_row8_col0" class="data row8 col0" >0.770499</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row9" class="row_heading level0 row9" >PCIAT-PCIAT_16</th>
#       <td id="T_c2033_row9_col0" class="data row9 col0" >0.769422</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row10" class="row_heading level0 row10" >PCIAT-PCIAT_10</th>
#       <td id="T_c2033_row10_col0" class="data row10 col0" >0.761463</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row11" class="row_heading level0 row11" >PCIAT-PCIAT_20</th>
#       <td id="T_c2033_row11_col0" class="data row11 col0" >0.754277</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row12" class="row_heading level0 row12" >PCIAT-PCIAT_19</th>
#       <td id="T_c2033_row12_col0" class="data row12 col0" >0.737243</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row13" class="row_heading level0 row13" >PCIAT-PCIAT_01</th>
#       <td id="T_c2033_row13_col0" class="data row13 col0" >0.727959</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row14" class="row_heading level0 row14" >PCIAT-PCIAT_14</th>
#       <td id="T_c2033_row14_col0" class="data row14 col0" >0.721995</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row15" class="row_heading level0 row15" >PCIAT-PCIAT_09</th>
#       <td id="T_c2033_row15_col0" class="data row15 col0" >0.720953</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row16" class="row_heading level0 row16" >PCIAT-PCIAT_06</th>
#       <td id="T_c2033_row16_col0" class="data row16 col0" >0.703261</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row17" class="row_heading level0 row17" >PCIAT-PCIAT_11</th>
#       <td id="T_c2033_row17_col0" class="data row17 col0" >0.684780</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row18" class="row_heading level0 row18" >PCIAT-PCIAT_04</th>
#       <td id="T_c2033_row18_col0" class="data row18 col0" >0.625394</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row19" class="row_heading level0 row19" >PCIAT-PCIAT_07</th>
#       <td id="T_c2033_row19_col0" class="data row19 col0" >0.491768</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row20" class="row_heading level0 row20" >PCIAT-PCIAT_12</th>
#       <td id="T_c2033_row20_col0" class="data row20 col0" >0.412194</td>
#     </tr>
#     <tr>
#       <th id="T_c2033_level0_row21" class="row_heading level0 row21" >PCIAT-Season</th>
#       <td id="T_c2033_row21_col0" class="data row21 col0" >0.015487</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Number of sii=0:",len(train[train['PCIAT-PCIAT_Total']<=30]))
print("Number of sii=1:",len(train[(30<train['PCIAT-PCIAT_Total'])&(train['PCIAT-PCIAT_Total']<50)]))
print("Number of sii=2:",len(train[(50<=train['PCIAT-PCIAT_Total'])&(train['PCIAT-PCIAT_Total']<80)]))
print("Number of sii=3:",len(train[train['PCIAT-PCIAT_Total']>=80]))
# Out:
# Number of sii=0: 1594
# Number of sii=1: 730
# Number of sii=2: 378
# Number of sii=3: 34

# %%
PCIAT_cols.remove('PCIAT-PCIAT_Total')
backup_train = train
train.drop(columns=PCIAT_cols,inplace=True)

# %%
print("Number of possible values for PIU:",len(train['PreInt_EduHx-computerinternet_hoursday'].unique())) # It can be 0,1,2,3 or NaN
# Out:
# Number of possible values for PIU: 5

# %%
print("Correlation between PIU and sii:", train['PreInt_EduHx-computerinternet_hoursday'].corr(train['sii']))
# Out:
# Correlation between PIU and sii: 0.3365255344349211

# %%
feature_correlation = pd.DataFrame(train.drop(columns=['sii','BIA-BIA_BMI','SDS-SDS_Total_Raw']).corr()['PCIAT-PCIAT_Total'].sort_values(ascending=False))
feature_correlation.style.background_gradient()

# drop BIA-BIA_BMI because it has been already calculated in `Physical-BMI`
# Same reason with 'SDS-SDS_Total_Raw'
# Out:
# <style type="text/css">
# #T_2b652_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2b652_row1_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_2b652_row2_col0 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_2b652_row3_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_2b652_row4_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_2b652_row5_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_2b652_row6_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_2b652_row7_col0, #T_2b652_row8_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_2b652_row9_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_2b652_row10_col0, #T_2b652_row11_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_2b652_row12_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_2b652_row13_col0, #T_2b652_row14_col0 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_2b652_row15_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_2b652_row16_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_2b652_row17_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_2b652_row18_col0, #T_2b652_row19_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_2b652_row20_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_2b652_row21_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_2b652_row22_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_2b652_row23_col0, #T_2b652_row24_col0, #T_2b652_row25_col0 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_2b652_row26_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_2b652_row27_col0, #T_2b652_row28_col0, #T_2b652_row29_col0, #T_2b652_row30_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_2b652_row31_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_2b652_row32_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_2b652_row33_col0, #T_2b652_row34_col0, #T_2b652_row35_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_2b652_row36_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_2b652_row37_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_2b652_row38_col0, #T_2b652_row39_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_2b652_row40_col0, #T_2b652_row41_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_2b652_row42_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_2b652_row43_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_2b652_row44_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_2b652_row45_col0, #T_2b652_row46_col0, #T_2b652_row47_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_2b652_row48_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_2b652_row49_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2b652_row50_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_2b652_row51_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_2b652_row52_col0, #T_2b652_row53_col0, #T_2b652_row54_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_2b652_row55_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_2b652_row56_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2b652">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b652_level0_col0" class="col_heading level0 col0" >PCIAT-PCIAT_Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b652_level0_row0" class="row_heading level0 row0" >PCIAT-PCIAT_Total</th>
#       <td id="T_2b652_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row1" class="row_heading level0 row1" >Physical-Height</th>
#       <td id="T_2b652_row1_col0" class="data row1 col0" >0.420765</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row2" class="row_heading level0 row2" >Basic_Demos-Age</th>
#       <td id="T_2b652_row2_col0" class="data row2 col0" >0.409559</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row3" class="row_heading level0 row3" >PreInt_EduHx-computerinternet_hoursday</th>
#       <td id="T_2b652_row3_col0" class="data row3 col0" >0.374124</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row4" class="row_heading level0 row4" >Physical-Weight</th>
#       <td id="T_2b652_row4_col0" class="data row4 col0" >0.353048</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row5" class="row_heading level0 row5" >Physical-Waist_Circumference</th>
#       <td id="T_2b652_row5_col0" class="data row5 col0" >0.327013</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row6" class="row_heading level0 row6" >FGC-FGC_CU</th>
#       <td id="T_2b652_row6_col0" class="data row6 col0" >0.287494</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row7" class="row_heading level0 row7" >Physical-BMI</th>
#       <td id="T_2b652_row7_col0" class="data row7 col0" >0.240858</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row8" class="row_heading level0 row8" >SDS-SDS_Total_T</th>
#       <td id="T_2b652_row8_col0" class="data row8 col0" >0.237718</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row9" class="row_heading level0 row9" >PAQ_A-Season</th>
#       <td id="T_2b652_row9_col0" class="data row9 col0" >0.219292</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row10" class="row_heading level0 row10" >FGC-FGC_PU</th>
#       <td id="T_2b652_row10_col0" class="data row10 col0" >0.196006</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row11" class="row_heading level0 row11" >BIA-BIA_Frame_num</th>
#       <td id="T_2b652_row11_col0" class="data row11 col0" >0.193631</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row12" class="row_heading level0 row12" >FGC-FGC_GSD</th>
#       <td id="T_2b652_row12_col0" class="data row12 col0" >0.160472</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row13" class="row_heading level0 row13" >Physical-Systolic_BP</th>
#       <td id="T_2b652_row13_col0" class="data row13 col0" >0.147081</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row14" class="row_heading level0 row14" >FGC-FGC_GSND</th>
#       <td id="T_2b652_row14_col0" class="data row14 col0" >0.146813</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row15" class="row_heading level0 row15" >FGC-FGC_TL</th>
#       <td id="T_2b652_row15_col0" class="data row15 col0" >0.136696</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row16" class="row_heading level0 row16" >PAQ_C-Season</th>
#       <td id="T_2b652_row16_col0" class="data row16 col0" >0.115316</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row17" class="row_heading level0 row17" >BIA-BIA_FFMI</th>
#       <td id="T_2b652_row17_col0" class="data row17 col0" >0.109694</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row18" class="row_heading level0 row18" >BIA-BIA_FMI</th>
#       <td id="T_2b652_row18_col0" class="data row18 col0" >0.085863</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row19" class="row_heading level0 row19" >BIA-BIA_Activity_Level_num</th>
#       <td id="T_2b652_row19_col0" class="data row19 col0" >0.084548</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row20" class="row_heading level0 row20" >BIA-BIA_LST</th>
#       <td id="T_2b652_row20_col0" class="data row20 col0" >0.075623</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row21" class="row_heading level0 row21" >Physical-Diastolic_BP</th>
#       <td id="T_2b652_row21_col0" class="data row21 col0" >0.069321</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row22" class="row_heading level0 row22" >FGC-FGC_PU_Zone</th>
#       <td id="T_2b652_row22_col0" class="data row22 col0" >0.056973</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row23" class="row_heading level0 row23" >BIA-BIA_DEE</th>
#       <td id="T_2b652_row23_col0" class="data row23 col0" >0.053094</td>
#     </tr>
#     <tr>
#       <th id="T_2b652_level0_row24" class="row_heading level0 row24" >BIA-BIA_SMM</th>
#       <td id="T_2b652_row24_col0" class="data row24 col0" >0.052912</td>
#     </tr>
#     <tr>
#       <th id="T_2b

# %%
# only take columns that have |correlation| >= 0.1
remain = feature_correlation[abs(feature_correlation['PCIAT-PCIAT_Total'])>=0.1].drop('PCIAT-PCIAT_Total')
remain_features = remain.index.tolist()
remain.style.background_gradient()
# Out:
# <style type="text/css">
# #T_82258_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_82258_row1_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_82258_row2_col0 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_82258_row3_col0 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_82258_row4_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_82258_row5_col0 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_82258_row6_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_82258_row7_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_82258_row8_col0 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_82258_row9_col0 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_82258_row10_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_82258_row11_col0 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_82258_row12_col0, #T_82258_row13_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_82258_row14_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_82258_row15_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_82258_row16_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_82258_row17_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_82258_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_82258">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82258_level0_col0" class="col_heading level0 col0" >PCIAT-PCIAT_Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82258_level0_row0" class="row_heading level0 row0" >Physical-Height</th>
#       <td id="T_82258_row0_col0" class="data row0 col0" >0.420765</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row1" class="row_heading level0 row1" >Basic_Demos-Age</th>
#       <td id="T_82258_row1_col0" class="data row1 col0" >0.409559</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row2" class="row_heading level0 row2" >PreInt_EduHx-computerinternet_hoursday</th>
#       <td id="T_82258_row2_col0" class="data row2 col0" >0.374124</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row3" class="row_heading level0 row3" >Physical-Weight</th>
#       <td id="T_82258_row3_col0" class="data row3 col0" >0.353048</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row4" class="row_heading level0 row4" >Physical-Waist_Circumference</th>
#       <td id="T_82258_row4_col0" class="data row4 col0" >0.327013</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row5" class="row_heading level0 row5" >FGC-FGC_CU</th>
#       <td id="T_82258_row5_col0" class="data row5 col0" >0.287494</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row6" class="row_heading level0 row6" >Physical-BMI</th>
#       <td id="T_82258_row6_col0" class="data row6 col0" >0.240858</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row7" class="row_heading level0 row7" >SDS-SDS_Total_T</th>
#       <td id="T_82258_row7_col0" class="data row7 col0" >0.237718</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row8" class="row_heading level0 row8" >PAQ_A-Season</th>
#       <td id="T_82258_row8_col0" class="data row8 col0" >0.219292</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row9" class="row_heading level0 row9" >FGC-FGC_PU</th>
#       <td id="T_82258_row9_col0" class="data row9 col0" >0.196006</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row10" class="row_heading level0 row10" >BIA-BIA_Frame_num</th>
#       <td id="T_82258_row10_col0" class="data row10 col0" >0.193631</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row11" class="row_heading level0 row11" >FGC-FGC_GSD</th>
#       <td id="T_82258_row11_col0" class="data row11 col0" >0.160472</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row12" class="row_heading level0 row12" >Physical-Systolic_BP</th>
#       <td id="T_82258_row12_col0" class="data row12 col0" >0.147081</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row13" class="row_heading level0 row13" >FGC-FGC_GSND</th>
#       <td id="T_82258_row13_col0" class="data row13 col0" >0.146813</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row14" class="row_heading level0 row14" >FGC-FGC_TL</th>
#       <td id="T_82258_row14_col0" class="data row14 col0" >0.136696</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row15" class="row_heading level0 row15" >PAQ_C-Season</th>
#       <td id="T_82258_row15_col0" class="data row15 col0" >0.115316</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row16" class="row_heading level0 row16" >BIA-BIA_FFMI</th>
#       <td id="T_82258_row16_col0" class="data row16 col0" >0.109694</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row17" class="row_heading level0 row17" >FGC-FGC_SRR_Zone</th>
#       <td id="T_82258_row17_col0" class="data row17 col0" >-0.109682</td>
#     </tr>
#     <tr>
#       <th id="T_82258_level0_row18" class="row_heading level0 row18" >FGC-FGC_SRL_Zone</th>
#       <td id="T_82258_row18_col0" class="data row18 col0" >-0.148850</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Number of features before remove low correlate features:", feature_correlation.shape[0] - 2) # minus 2 because we don't count 'sii' and 'PCIAT-PCIAT_Total' as features
print("Number of remain features:", len(remain_features))
# Out:
# Number of features before remove low correlate features: 55
# Number of remain features: 19

# %%
missing = pd.DataFrame(train.isna().sum().sort_values(ascending=False)).rename(columns={0:"Missing Count"})
missing['Data Loss(%)'] = missing['Missing Count'] / train.shape[0] * 100
missing.style.background_gradient()
# Out:
# <style type="text/css">
# #T_8939e_row0_col0, #T_8939e_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8939e_row1_col0, #T_8939e_row1_col1, #T_8939e_row2_col0, #T_8939e_row2_col1, #T_8939e_row3_col0, #T_8939e_row3_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_8939e_row4_col0, #T_8939e_row4_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_8939e_row5_col0, #T_8939e_row5_col1, #T_8939e_row6_col0, #T_8939e_row6_col1 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_8939e_row7_col0, #T_8939e_row7_col1, #T_8939e_row8_col0, #T_8939e_row8_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_8939e_row9_col0, #T_8939e_row9_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_8939e_row10_col0, #T_8939e_row10_col1, #T_8939e_row11_col0, #T_8939e_row11_col1, #T_8939e_row12_col0, #T_8939e_row12_col1, #T_8939e_row13_col0, #T_8939e_row13_col1, #T_8939e_row14_col0, #T_8939e_row14_col1, #T_8939e_row15_col0, #T_8939e_row15_col1, #T_8939e_row16_col0, #T_8939e_row16_col1, #T_8939e_row17_col0, #T_8939e_row17_col1, #T_8939e_row18_col0, #T_8939e_row18_col1, #T_8939e_row19_col0, #T_8939e_row19_col1, #T_8939e_row20_col0, #T_8939e_row20_col1, #T_8939e_row21_col0, #T_8939e_row21_col1, #T_8939e_row22_col0, #T_8939e_row22_col1, #T_8939e_row23_col0, #T_8939e_row23_col1, #T_8939e_row24_col0, #T_8939e_row24_col1, #T_8939e_row25_col0, #T_8939e_row25_col1 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_8939e_row26_col0, #T_8939e_row26_col1, #T_8939e_row27_col0, #T_8939e_row27_col1, #T_8939e_row28_col0, #T_8939e_row28_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_8939e_row29_col0, #T_8939e_row29_col1, #T_8939e_row30_col0, #T_8939e_row30_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_8939e_row31_col0, #T_8939e_row31_col1, #T_8939e_row32_col0, #T_8939e_row32_col1, #T_8939e_row33_col0, #T_8939e_row33_col1 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_8939e_row34_col0, #T_8939e_row34_col1, #T_8939e_row35_col0, #T_8939e_row35_col1 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_8939e_row36_col0, #T_8939e_row36_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_8939e_row37_col0, #T_8939e_row37_col1, #T_8939e_row38_col0, #T_8939e_row38_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_8939e_row39_col0, #T_8939e_row39_col1, #T_8939e_row40_col0, #T_8939e_row40_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_8939e_row41_col0, #T_8939e_row41_col1, #T_8939e_row42_col0, #T_8939e_row42_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_8939e_row43_col0, #T_8939e_row43_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_8939e_row44_col0, #T_8939e_row44_col1, #T_8939e_row45_col0, #T_8939e_row45_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_8939e_row46_col0, #T_8939e_row46_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_8939e_row47_col0, #T_8939e_row47_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_8939e_row48_col0, #T_8939e_row48_col1, #T_8939e_row49_col0, #T_8939e_row49_col1, #T_8939e_row50_col0, #T_8939e_row50_col1, #T_8939e_row51_col0, #T_8939e_row51_col1, #T_8939e_row52_col0, #T_8939e_row52_col1, #T_8939e_row53_col0, #T_8939e_row53_col1, #T_8939e_row54_col0, #T_8939e_row54_col1, #T_8939e_row55_col0, #T_8939e_row55_col1, #T_8939e_row56_col0, #T_8939e_row56_col1, #T_8939e_row57_col0, #T_8939e_row57_col1, #T_8939e_row58_col0, #T_8939e_row58_col1, #T_8939e_row59_col0, #T_8939e_row59_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_8939e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8939e_level0_col0" class="col_heading level0 col0" >Missing Count</th>
#       <th id="T_8939e_level0_col1" class="col_heading level0 col1" >Data Loss(%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8939e_level0_row0" class="row_heading level0 row0" >PAQ_A-PAQ_A_Total</th>
#       <td id="T_8939e_row0_col0" class="data row0 col0" >3485</td>
#       <td id="T_8939e_row0_col1" class="data row0 col1" >88.005051</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row1" class="row_heading level0 row1" >Fitness_Endurance-Time_Sec</th>
#       <td id="T_8939e_row1_col0" class="data row1 col0" >3220</td>
#       <td id="T_8939e_row1_col1" class="data row1 col1" >81.313131</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row2" class="row_heading level0 row2" >Fitness_Endurance-Time_Mins</th>
#       <td id="T_8939e_row2_col0" class="data row2 col0" >3220</td>
#       <td id="T_8939e_row2_col1" class="data row2 col1" >81.313131</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row3" class="row_heading level0 row3" >Fitness_Endurance-Max_Stage</th>
#       <td id="T_8939e_row3_col0" class="data row3 col0" >3217</td>
#       <td id="T_8939e_row3_col1" class="data row3 col1" >81.237374</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row4" class="row_heading level0 row4" >Physical-Waist_Circumference</th>
#       <td id="T_8939e_row4_col0" class="data row4 col0" >3062</td>
#       <td id="T_8939e_row4_col1" class="data row4 col1" >77.323232</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row5" class="row_heading level0 row5" >FGC-FGC_GSND_Zone</th>
#       <td id="T_8939e_row5_col0" class="data row5 col0" >2898</td>
#       <td id="T_8939e_row5_col1" class="data row5 col1" >73.181818</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row6" class="row_heading level0 row6" >FGC-FGC_GSD_Zone</th>
#       <td id="T_8939e_row6_col0" class="data row6 col0" >2897</td>
#       <td id="T_8939e_row6_col1" class="data row6 col1" >73.156566</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row7" class="row_heading level0 row7" >FGC-FGC_GSD</th>
#       <td id="T_8939e_row7_col0" class="data row7 col0" >2886</td>
#       <td id="T_8939e_row7_col1" class="data row7 col1" >72.878788</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row8" class="row_heading level0 row8" >FGC-FGC_GSND</th>
#       <td id="T_8939e_row8_col0" class="data row8 col0" >2886</td>
#       <td id="T_8939e_row8_col1" class="data row8 col1" >72.878788</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row9" class="row_heading level0 row9" >PAQ_C-PAQ_C_Total</th>
#       <td id="T_8939e_row9_col0" class="data row9 col0" >2239</td>
#       <td id="T_8939e_row9_col1" class="data row9 col1" >56.540404</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row10" class="row_heading level0 row10" >BIA-BIA_BMI</th>
#       <td id="T_8939e_row10_col0" class="data row10 col0" >1969</td>
#       <td id="T_8939e_row10_col1" class="data row10 col1" >49.722222</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row11" class="row_heading level0 row11" >BIA-BIA_BMC</th>
#       <td id="T_8939e_row11_col0" class="data row11 col0" >1969</td>
#       <td id="T_8939e_row11_col1" class="data row11 col1" >49.722222</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row12" class="row_heading level0 row12" >BIA-BIA_FFMI</th>
#       <td id="T_8939e_row12_col0" class="data row12 col0" >1969</td>
#       <td id="T_8939e_row12_col1" class="data row12 col1" >49.722222</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row13" class="row_heading level0 row13" >BIA-BIA_Activity_Level_num</th>
#       <td id="T_8939e_row13_col0" class="data row13 col0" >1969</td>
#       <td id="T_8939e_row13_col1" class="data row13 col1" >49.722222</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row14" class="row_heading level0 row14" >BIA-BIA_FMI</th>
#       <td id="T_8939e_row14_col0" class="data row14 col0" >1969</td>
#       <td id="T_8939e_row14_col1" class="data row14 col1" >49.722222</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row15" class="row_heading level0 row15" >BIA-BIA_Fat</th>
#       <td id="T_8939e_row15_col0" class="data row15 col0" >1969</td>
#       <td id="T_8939e_row15_col1" class="data row15 col1" >49.722222</td>
#     </tr>
#     <tr>
#       <th id="T_8939e_level0_row16" class="row_heading level0 row16" >BIA-BIA_BMR</th>
#       <td id="T_8939e_row16_col0" class="data row16 col

# %%
drop_threshold = 70 # Drop column that misses more than 70% of its value
remain_features = [ft for ft in remain_features if ft in missing[missing['Data Loss(%)']<=70].index.tolist()]
remain_features
print("Number of remain features:", len(remain_features))
# Out:
# Number of remain features: 16

# %%
remain_features
# Out:
# ['Physical-Height',
#  'Basic_Demos-Age',
#  'PreInt_EduHx-computerinternet_hoursday',
#  'Physical-Weight',
#  'FGC-FGC_CU',
#  'Physical-BMI',
#  'SDS-SDS_Total_T',
#  'PAQ_A-Season',
#  'FGC-FGC_PU',
#  'BIA-BIA_Frame_num',
#  'Physical-Systolic_BP',
#  'FGC-FGC_TL',
#  'PAQ_C-Season',
#  'BIA-BIA_FFMI',
#  'FGC-FGC_SRR_Zone',
#  'FGC-FGC_SRL_Zone']

# %%
train[remain_features].hist(figsize=(10,10), grid = True)
plt.tight_layout()

# %% [markdown]
# ## Train Model

# %% [markdown]
# I (Hoang) use XGB here (Khanh and Hung will test other models)

# %%
nonNaN_train = train.dropna(subset=['sii'])
X_train, X_test = nonNaN_train[remain_features], test[remain_features]
target_train = nonNaN_train['PCIAT-PCIAT_Total']

# %%
def scale(raw,coef):
    return raw*coef

# Convert PCIAT_Total score -> category
def score_to_category(scores):
    scores = np.array(scores)*1.252
    bins = np.zeros_like(scores)
    bins[scores <= 30] = 0
    bins[(scores > 30) & (scores < 50)] = 1
    bins[(scores >= 50) & (scores < 80)] = 2
    bins[scores >= 80] = 3
    return bins

def quadratic_kappa(y_pred, y_true):
    y_true_categories, y_pred_categories = score_to_category(y_true), score_to_category(y_pred)
    return cohen_kappa_score(y_true_categories, y_pred_categories, weights='quadratic')

# %%
scorer = make_scorer(quadratic_kappa, greater_is_better=True)
params = {'max_depth': 3, 'n_estimators': 59, 'learning_rate': 0.07327652118259573, 'subsample': 0.5968194045365575, 'colsample_bytree': 0.9123669348125403}
skf = StratifiedKFold(n_splits=10)
model = xgb.XGBRegressor(**params)
scores = cross_val_score(model, X_train, target_train, cv=skf, scoring=scorer)
print("QWK Scores:", scores)
print("Mean QWK Score:", np.mean(scores))
# Out:
# QWK Scores: [0.39409546 0.47568    0.53216011 0.45032819 0.50378405 0.40749026
#  0.46099897 0.40880839 0.44988701 0.47003669]
# Mean QWK Score: 0.4553269130119471

# %%
model.fit(X_train,target_train)
feature_imp = pd.Series(model.feature_importances_,index=X_train.columns).sort_values(ascending=False)
feature_imp
# Out:
# Basic_Demos-Age                           0.237255
# Physical-Height                           0.138153
# PreInt_EduHx-computerinternet_hoursday    0.117180
# SDS-SDS_Total_T                           0.077912
# FGC-FGC_CU                                0.052998
# Physical-Weight                           0.046943
# FGC-FGC_PU                                0.042593
# PAQ_A-Season                              0.041014
# BIA-BIA_Frame_num                         0.040792
# FGC-FGC_SRL_Zone                          0.039664
# Physical-BMI                              0.036555
# PAQ_C-Season                              0.035107
# Physical-Systolic_BP                      0.032174
# BIA-BIA_FFMI                              0.030833
# FGC-FGC_TL                                0.030826
# FGC-FGC_SRR_Zone                          0.000000
# dtype: float32

# %%
preds = model.predict(X_test)
preds = pd.Series(score_to_category(preds))
preds.index = test.index
preds.to_csv('submission.csv')
